# %%
import pandas as pd

# %%
iris_data = pd.read_csv('./dataset/Iris.csv')

# %%
iris_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
iris_data.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
iris_data.loc[iris_data['PetalWidthCm'] > 1.5, ['Id','PetalWidthCm','Species']]
# Out:
#       Id  PetalWidthCm          Species
# 56    57           1.6  Iris-versicolor
# 70    71           1.8  Iris-versicolor
# 77    78           1.7  Iris-versicolor
# 83    84           1.6  Iris-versicolor
# 85    86           1.6  Iris-versicolor
# 100  101           2.5   Iris-virginica
# 101  102           1.9   Iris-virginica
# 102  103           2.1   Iris-virginica
# 103  104           1.8   Iris-virginica
# 104  105           2.2   Iris-virginica
# 105  106           2.1   Iris-virginica
# 106  107           1.7   Iris-virginica
# 107  108           1.8   Iris-virginica
# 108  109           1.8   Iris-virginica
# 109  110           2.5   Iris-virginica
# 110  111           2.0   Iris-virginica
# 111  112           1.9   Iris-virginica
# 112  113           2.1   Iris-virginica
# 113  114           2.0   Iris-virginica
# 114  115           2.4   Iris-virginica
# 115  116           2.3   Iris-virginica
# 116  117           1.8   Iris-virginica
# ...

# %%
iris_data.loc[(iris_data['Species'] == 'Iris-virginica') & (iris_data['Species'] == 'Iris-setosa')]
# Out:
# Empty DataFrame
# Columns: [Id, SepalLengthCm, SepalWidthCm, PetalLengthCm, PetalWidthCm, Species]
# Index: []
